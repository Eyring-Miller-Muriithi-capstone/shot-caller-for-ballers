# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import os
import time

# Endpoints from NBA API
from nba_api.stats.endpoints import playbyplayv2
from nba_api.stats.endpoints import gamerotation
from nba_api.stats.endpoints import shotchartdetail
from nba_api.stats.endpoints import teamplayerdashboard
from nba_api.stats.endpoints import winprobabilitypbp

# Static Imports from NBA API
from nba_api.stats.static import players
from nba_api.stats.static import teams
from acquire import player_season_3pa
# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
import acquire
# Modeling
from sklearn.cluster import KMeans
# import lux

# Helpful Stuff
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
pip install lux-api
# Out:
# Requirement already satisfied: lux-api in /usr/local/anaconda3/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: autopep8>=1.5 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (1.5.7)
# Requirement already satisfied: altair>=4.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (4.2.0)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (1.7.1)
# Requirement already satisfied: lux-widget>=0.1.4 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (0.1.11)
# Requirement already satisfied: psutil>=5.9.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (5.9.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (3.4.3)
# Requirement already satisfied: sh in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (1.14.3)
# Requirement already satisfied: iso3166 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (2.1.1)
# Requirement already satisfied: pandas in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (1.3.4)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (1.20.3)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-api) (0.24.2)
# Requirement already satisfied: entrypoints in /usr/local/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api) (0.3)
# Requirement already satisfied: jinja2 in /usr/local/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api) (2.11.3)
# Requirement already satisfied: toolz in /usr/local/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api) (0.11.1)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from altair>=4.0.0->lux-api) (3.2.0)
# Requirement already satisfied: pycodestyle>=2.7.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from autopep8>=1.5->lux-api) (2.7.0)
# Requirement already satisfied: toml in /usr/local/anaconda3/lib/python3.9/site-packages (from autopep8>=1.5->lux-api) (0.10.2)
# Requirement already satisfied: pyrsistent>=0.14.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (0.18.0)
# Requirement already satisfied: setuptools in /usr/local/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (58.0.4)
# Requirement already satisfied: six>=1.11.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (1.16.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api) (21.2.0)
# Requirement already satisfied: ipywidgets>=7.5.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-widget>=0.1.4->lux-api) (7.6.5)
# Requirement already satisfied: notebook>=4.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from lux-widget>=0.1.4->lux-api) (6.4.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.4.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.0.0)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (7.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.2)
# Requirement already satisfied: appnope in /usr/local/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (6.1.12)
# Requirement already satisfied: backcall in /usr/local/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.10.0)
# Requirement already satisfied: pickleshare in /usr/local/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (3.0.20)
# Requirement already satisfied: decorator in /usr/local/anaconda3/lib/python3.9/site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (5.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (22.2.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (4.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.0->lux-api) (0.10.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.9.4)
# Requirement already satisfied: Send2Trash>=1.5.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.11.0)
# Requirement already satisfied: argon2-cffi in /usr/local/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (20.1.0)
# Requirement already satisfied: nbconvert in /usr/local/anaconda3/lib/python3.9/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (6.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/anaconda3/lib/python3.9/site-packages (from pandas->lux-api) (2021.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api) (0.2.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->lux-api) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->lux-api) (2.2.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (2.20)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/anaconda3/lib/python3.9/site-packages (from jinja2->altair>=4.0.0->lux-api) (2.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.4.3)
# Requirement already satisfied: testpath in /usr/local/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.1.2)
# Requirement already satisfied: bleach in /usr/local/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (4.0.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /usr/local/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.3)
# Requirement already satisfied: defusedxml in /usr/local/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.7.1)
# Requirement already satisfied: nest-asyncio in /usr/local/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.5.1)
# Requirement already satisfied: async-generator in /usr/local/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (1.10)
# Requirement already satisfied: packaging in /usr/local/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (21.0)
# Requirement already satisfied: webencodings in /usr/local/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.0.0->lux-widget>=0.1.4->lux-api) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# jupyter nbextension install --py luxwidget

# %%
# lux.logger = True

# %%
error_players = []
while True:
    try:
        booo = player_season_3pa("Tyrese Maxey")
        break
    except IndexError:
        error_players.append('Tyrese Maxey')
        print('index out of range')
        break
    except UnboundLocalError:
        error_players.append()
    except KeyError:
        error_players.append
        
print(error_players)
print('done')
# Out:
# Loading game 60 of 75
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/qg/y1d1577d6_zdj2rfwsn6lwsh0000gn/T/ipykernel_77993/3184533323.py in <module>
#       2 while True:
#       3     try:
# ----> 4         booo = player_season_3pa("Tyrese Maxey")
#       5         break
#       6     except IndexError:
#
# ~/codeup-data-science/shot-caller-for-ballers/Notebooks/Lincoln/acquire.py in player_season_3pa(player_full_name)
#     340     for game in game_id_list:
#     341         print(f'\rLoading game {count} of {len(game_id_list)}', end='')
# --> 342         df_game = acquire_player_game_target(game, player_id, df_shots)
#     343         df_player_season = pd.concat([df_player_season,df_game])
#     344         count += 1
#
# ~/codeup-data-science/shot-caller-for-ballers/Notebooks/Lincoln/acquire.py in acquire_player_game_target(game_id, player_id, df_shots)
#     315     df_game_shots = get_player_game_shots(game_id, player_id, df_shots)
#     316
# --> 317     df_player_game = player_game(df_game_shots, df_player_game)
#     318
#     319     df_player_game_target = clean_game(df_player_game)
#
# ~/codeup-data-science/shot-caller-for-ballers/Notebooks/Lincoln/acquire.py in player_game(df_game_shots, df_player_game)
#     231     df_player_game = df_player_game.merge(df_game_shots, how = 'inner', on = 'abs_time')
#     232     df_player_game['score_margin'] = np.where(df_player_game.home == True, df_player_game.HOME_SCORE_MARGIN, df_player_game.HOME_SCORE_MARGIN * -1)
# --> 233     if df_player_game.loc[0,'home'] == True:
#     234         df_player_game = df_player_game.drop(columns = ['VISITOR_PCT'])
#     235         df_player_game = df_player_game.rename(columns = {'HOME_PCT':"WIN_PCT"})
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1098     def _getitem_tuple(self, tup: tuple):
#    1099         with suppress(IndexingError):
# -> 1100             return self._getitem_lowerdim(tup)
#    1101
#    1102         # no multi-index, so validate all of the indexers
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     836                 # We don't need to check for tuples here because those are
#     837                 #  caught by the _is_nested_tuple_indexer check above.
# --> 838                 section = self._getitem_axis(key, axis=i)
#     839
#     840                 # We should never have a scalar section here, because
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3774                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3775         else:
# -> 3776             loc = index.get_loc(key)
#    3777
#    3778             if isinstance(loc, np.ndarray):
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %%
booo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/qg/y1d1577d6_zdj2rfwsn6lwsh0000gn/T/ipykernel_77993/1744019047.py in <module>
# ----> 1 booo
#
# NameError: name 'booo' is not defined

# %%
namelist_df = pd.read_csv("player_name copy.csv")
namelist = namelist_df.values.tolist()

# %%
final_list=[]
for i in namelist:
    final_list = final_list + i

# %%
len(final_list)
# Out:
# 86535

# %%
len(set(final_list))
# Out:
# 561

# %%
#list of 3pt players
overall_df = pd.read_csv('all_players_3pa.csv')
temp_df = pd.DataFrame()
error_players =[]
our_dfs = []

saved_players =list(overall_df.player.unique())
final_list = list(set(final_list))

[final_list.remove(name) for name in saved_players]

for name in final_list:
    print(f"Starting {name}")
    while True:
        try:
            print(f'Finished {name}')
            temp_df=player_season_3pa(name)
            our_dfs.append(temp_df)
            overall_df = pd.concat([overall_df, temp_df],ignore_index = True)
            pd.concat(our_dfs, ignore_index=True).to_csv('all_players_3pa2.csv', index=False)
            print(f"Finished {name}")
            break
            #put finish and loading statement on the same print statement
        except IndexError:
            print(f'{name} had an IndexError.')
            error_players.append(f'{name} IndexError')
            break
        except UnboundLocalError:
            print(f'{name} had a UnboundLocalError.')
            error_players.append(f'{name} UnboundLocalError')
            break
        except KeyError:
            print(f'{name} had a keyerror')
            error_players.append(f'{name} KeyError')
            break
        except:
            print('sleeping...')
            time.sleep(10)
            
print(overall_df)
# Out:
# Starting Kelly Oubre Jr.
# Finished Kelly Oubre Jr.
# Loading game 76 of 76Finished Kelly Oubre Jr.
# Starting Ja Morant
# Finished Ja Morant
# Loading game 57 of 57Finished Ja Morant
# Starting Jabari Parker
# Finished Jabari Parker
# Loading game 10 of 10Finished Jabari Parker
# Starting Brandon Goodwin
# Finished Brandon Goodwin
# Loading game 32 of 32Finished Brandon Goodwin
# Starting Gabe York
# Finished Gabe York
# Gabe York had an IndexError.
# Starting Jarred Vanderbilt
# Finished Jarred Vanderbilt
# Loading game 72 of 72Finished Jarred Vanderbilt
# Starting Jay Scrubb
# Finished Jay Scrubb
# Loading game 1 of 15Jay Scrubb had an IndexError.
# Starting Derrick Jones Jr.
# Finished Derrick Jones Jr.
# Loading game 48 of 48Finished Derrick Jones Jr.
# Starting Hassani Gravett
# Finished Hassani Gravett
# Starting Kessler Edwards
# Finished Kessler Edwards
# Loading game 46 of 46Finished Kessler Edwards
# Starting Shaquille Harrison
# Finished Shaquille Harrison
# Loading game 1 of 1Finished Shaquille Harrison
# Starting Ricky Rubio
# Finished Ricky Rubio
# Loading game 34 of 34Finished Ricky Rubio
# Starting P.J. Dozier
# Finished P.J. Dozier
# P.J. Dozier had an IndexError.
# Starting Kris Dunn
# Finished Kris Dunn
# Loading game 14 of 14Finished Kris Dunn
# Starting Montrezl Harrell
# Finished Montrezl Harrell
# Loading game 71 of 71Finished Montrezl Harrell
# Starting Bruce Brown
# Finished Bruce Brown
# Loading game 70 of 70Finished Bruce Brown
# Starting James Ennis III
# Finished James Ennis III
# Loading game 3 of 6James Ennis III had an IndexError.
# Starting Tim Hardaway Jr.
# Finished Tim Hardaway Jr.
# Loading game 42 of 42Finished Tim Hardaway Jr.
# Starting Moritz Wagner
# Finished Moritz Wagner
# Loading game 60 of 60Finished Moritz Wagner
# Starting Alex Len
# Finished Alex Len
# Loading game 38 of 38

# %%
overall_df.to_csv('overall_players_3pa.csv', index=False)

# %%
df_Curry
# Out:
#     win_prob  abs_time   game_id  player_id         player     team_id  \
# 0    0.44613       111  22100002     201939  Stephen Curry  1610612744
# 1    0.44769       139  22100002     201939  Stephen Curry  1610612744
# 2    0.44020       170  22100002     201939  Stephen Curry  1610612744
# 7    0.37707       719  22100002     201939  Stephen Curry  1610612744
# 8    0.37707       719  22100002     201939  Stephen Curry  1610612744
# ..       ...       ...       ...        ...            ...         ...
# 22       NaN      2642  22101025     201939  Stephen Curry  1610612744
# 0    0.60157        59  22101042     201939  Stephen Curry  1610612744
# 1    0.62661        76  22101042     201939  Stephen Curry  1610612744
# 2    0.48075       395  22101042     201939  Stephen Curry  1610612744
# 3    0.43000       454  22101042     201939  Stephen Curry  1610612744
#
#                      team  period  shot_result                  shot_type  \
# 0   Golden State Warriors       1  Missed Shot           Pullup Jump shot
# 1   Golden State Warriors       1  Missed Shot  Running Pull-Up Jump Shot
# 2   Golden State Warriors       1    Made Shot                  Jump Shot
# 7   Golden State Warriors       1  Missed Shot  Running Pull-Up Jump Shot
# 8   Golden State Warriors       1  Missed Shot  Running Pull-Up Jump Shot
# ..                    ...     ...          ...                        ...
# 22  Golden State Warriors       4    Made Shot        Step Back Jump shot
# 0   Golden State Warriors       1    Made Shot        Step Back Jump shot
# 1   Golden State Warriors       1  Missed Shot                  Jump Shot
# 2   Golden State Warriors       1  Missed Shot                  Jump Shot
# 3   Golden State Warriors       1  Missed Shot                  Jump Shot
#
#            fg_type  loc_x  loc_y                  zone   home  score_margin  \
# 0   3PT Field Goal   -109    260                Center  False             2
# 1   3PT Field Goal     48    257              L Center  False             2
# 2   3PT Field Goal   -165    189         L Above Break  False             3
# 7   3PT Field Goal    135    228         R Above Break  False            -2
# 8   3PT Field Goal    135    228         R Above Break  False            -2
# ..             ...    ...    ...                   ...    ...           ...
# 22  3PT Field Goal    228    110  L Below Break/Corner   True            13
# 0   3PT Field Goal   -210    155         L Above Break   True             1
# 1   3PT Field Goal   -207    140         L Above Break   True             1
# 2   3PT Field Goal    194    189  L Below Break/Corner   True            -6
# 3   3PT Field Goal   -165    250                Center   True            -8
#
#     points  fg_pct
# 0        0    1.00
# 1        0    0.00
# 2        3    0.00
# 7        5    0.29
# 8        5    0.25
# ..     ...     ...
# 22      37    0.64
# 0        3    1.00
# 1        3    1.00
# 2        3    0.50
# 3        3    0.33
#
# [714 rows x 18 columns]

# %%
df_teams = pd.DataFrame(teams.get_teams())
team_id_list = list(df_teams.id)

# %%
#finding MIN game with the most 3pts shots taken by Malik:
df_gameid = shotchartdetail.ShotChartDetail(team_id = 1610612744, player_id = 201939).get_data_frames()[0]
df_gameid[df_gameid.GAME_DATE == '20220309']
# Out:
# Empty DataFrame
# Columns: [GRID_TYPE, GAME_ID, GAME_EVENT_ID, PLAYER_ID, PLAYER_NAME, TEAM_ID, TEAM_NAME, PERIOD, MINUTES_REMAINING, SECONDS_REMAINING, EVENT_TYPE, ACTION_TYPE, SHOT_TYPE, SHOT_ZONE_BASIC, SHOT_ZONE_AREA, SHOT_ZONE_RANGE, SHOT_DISTANCE, LOC_X, LOC_Y, SHOT_ATTEMPTED_FLAG, SHOT_MADE_FLAG, GAME_DATE, HTM, VTM]
# Index: []

# %% [markdown]
# #### Save the player_id/team_id combo to a csv

# %%
filename = 'team_player_ids.csv'
if os.path.isfile(filename):
    team_player_ids =  pd.read_csv(filename, index_col=0)
else:
    players_list = []
    for team in team_id_list:
        df_tpd = teamplayerdashboard.TeamPlayerDashboard(team,
                                                         season = '2021-22').get_data_frames()
        player_list = list(df_tpd[1].PLAYER_ID)
        for player in player_list:
            row = [team,player]
            players_list.append(row)
    team_player_ids = pd.DataFrame(players_list, columns = ['team_id','player_id'])
    team_player_ids.to_csv('team_player_ids.csv')

# %% [markdown]
# ## Acquiring a dataframe of every shot taken from the 2021-2022 regular NBA season.

# %%
players_list = team_player_ids.values.tolist()

# %%
"""This function will acquire and cache .csv in notebook directory"""
filename2 = 'all_last_season_shots.csv'
if os.path.isfile(filename2):
    df_all_shots =  pd.read_csv(filename2, index_col=0)
else:
    players_list = []
    df = pd.DataFrame()
    index = 0
    for player in players_list:
        print(f'\rFetching index {index} of 714', end='')
        df_pl = shotchartdetail.ShotChartDetail(team_id = player[0],
                                                        player_id = player[1],
                                                        season_type_all_star='Regular Season',
                                                        season_nullable='2021-22',
                                                        context_measure_simple = 'FG3A').get_data_frames()
        time.sleep(.5)
        index += 1
        #df = pd.concat([df, df_pl[0]])
        #df.to_csv(filename2) these last two lines of code are looping and overwriting the current csv until last time 
        #through the loop.

# %% [markdown]
# ## Adding in only 3pt shots into the dataframe:
#
# -We are removing outliers by taking the sum of the lowest and highest quantile and multiplying by 1.5 to create an IQR upper bound (removing the anomaly shots that are opposite court-side and keeping the shots only with the 3pt shot range).

# %%
#calling in our df_all_shots dataframe and resetting index:
df_all_shots = df_all_shots.reset_index(drop = True)

# %%
#creating a df for only the 3pt shots taken:
df_all_3pt = df_all_shots[df_all_shots.SHOT_TYPE == '3PT Field Goal']

# %%
#Creating an IQR upper bound to remove the large anomaly 3pt shots taken.
low = df_all_3pt.SHOT_DISTANCE.quantile(.25)
high = df_all_3pt.SHOT_DISTANCE.quantile(.75)
add = (high-low) * 1.5
bound = high + add
#this is where our bound is:
bound
# Out:
# 29.0

# %%
#creating our bounds: any thing over 29ft in shot distance is in outliers df:
df_outlier_3pt = df_all_3pt[df_all_3pt.SHOT_DISTANCE > 29.0]

# %%
#anything less than 29 or equal to is now our df_3pt df:
df_3pt = df_all_3pt[df_all_3pt.SHOT_DISTANCE <= 29.0]

# %%
#recreating our main df to only hold those 3pt shots and IQR:
df_shots = df_all_shots[df_all_shots.SHOT_DISTANCE <= 29.0]

# %% [markdown]
# ### Clustering the 3pt shot locations (once outliers are taken out)

# %%
#creating our X variable:
X = df_3pt[['LOC_X','LOC_Y']]

# %%
#we found that using 7 kmean clusters gave us not only good 3pt
#area clusters, but also shots made in center court of the arch
kmeans = KMeans(n_clusters=7)
kmeans.fit(X)

clusters = kmeans.predict(X)

# %%
#we will add a new column onto our main df to hold these clusters:
df_3pt['three_pt_location'] = clusters

# %%
#plotting these 7clusters on the 3pt zone:
plt.figure(figsize = (14,12))
sns.scatterplot(data =df_3pt, x='LOC_X', y = 'LOC_Y', hue = 'three_pt_location')
plt.show()

# %% [markdown]
# ### We want to have descriptive names of each of these cluster zones.
# We are giving each of these clusters names by map their locations:

# %%
# creating a new column with the location names:
df_3pt['location'] = df_3pt['three_pt_location'].map({0: 'R Above Break', 1: 'L Above Break',2:'L Below Break/Corner',3:'R Center',4:'R Below Break/Corner',5:'Center',6:'L Center'})

# %%
#creating a variable to use for applying clusters to 3pt only shots
#note: 2pt shots will be NaN
location_column = df_3pt[['location']]

# %%
#merging the applying the clusters:
df_shots = df_shots.merge(location_column, how = 'left', left_index = True, right_index = True)

# %%
df_shots.head()
# Out:
#            GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID        PLAYER_NAME  \
# 0  Shot Chart Detail  22100014             42     203992  Bogdan Bogdanovic
# 1  Shot Chart Detail  22100014             47     203992  Bogdan Bogdanovic
# 2  Shot Chart Detail  22100014            305     203992  Bogdan Bogdanovic
# 3  Shot Chart Detail  22100014            362     203992  Bogdan Bogdanovic
# 4  Shot Chart Detail  22100014            433     203992  Bogdan Bogdanovic
#
#       TEAM_ID      TEAM_NAME  PERIOD  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612737  Atlanta Hawks       1                  8                 14
# 1  1610612737  Atlanta Hawks       1                  7                 47
# 2  1610612737  Atlanta Hawks       2                  1                 44
# 3  1610612737  Atlanta Hawks       3                  9                 40
# 4  1610612737  Atlanta Hawks       3                  4                 24
#
#     EVENT_TYPE                 ACTION_TYPE       SHOT_TYPE  \
# 0    Made Shot                   Jump Shot  3PT Field Goal
# 1    Made Shot                   Jump Shot  3PT Field Goal
# 2  Missed Shot  Driving Floating Jump Shot  2PT Field Goal
# 3    Made Shot                   Jump Shot  3PT Field Goal
# 4  Missed Shot                   Jump Shot  3PT Field Goal
#
#          SHOT_ZONE_BASIC         SHOT_ZONE_AREA  SHOT_ZONE_RANGE  \
# 0         Right Corner 3          Right Side(R)          24+ ft.
# 1      Above the Break 3  Right Side Center(RC)          24+ ft.
# 2  In The Paint (Non-RA)              Center(C)  Less Than 8 ft.
# 3         Right Corner 3          Right Side(R)          24+ ft.
# 4      Above the Break 3  Right Side Center(RC)          24+ ft.
#
#    SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  \
# 0             23    228     64                    1               1
# 1             24     91    232                    1               1
# 2              7      6     79                    1               0
# 3             23    228     69                    1               1
# 4             24    134    210                    1               0
#
#    GAME_DATE  HTM  VTM              location
# 0   20211021  ATL  DAL  L Below Break/Corner
# 1   20211021  ATL  DAL         R Above Break
# 2   20211021  ATL  DAL                   NaN
# 3   20211021  ATL  DAL  L Below Break/Corner
# 4   20211021  ATL  DAL         R Above Break

# %% [markdown]
# ## Let's see if this works!
# Creating a Test case using the Spurs and Malik Beasley.

# %%
team_id = teams.find_team_by_abbreviation('GSW')['id'] # For Minnesota Timberwolves

player_id = players.find_players_by_full_name("Stephen Curry")[0]['id'] # For Malik Beasley

game_id = '0022100002' # First game of year Spurs vs. Magic - note that game id must be converted to an int in df_shots

# %%
team_id
# Out:
# 1610612744

# %% [markdown]
# ### We are using the `win_probability` api endpoint for a base of the analysis dataframe.

# %%
# Select for a single game
df_base = winprobabilitypbp.WinProbabilityPBP(game_id).get_data_frames()[0]
df_base
# Out:
#          GAME_ID  EVENT_NUM  HOME_PCT  VISITOR_PCT  HOME_PTS  VISITOR_PTS  \
# 0     0022100002        2.0   0.58808      0.41192         0            0
# 1     0022100002        4.0   0.61352      0.38648         0            0
# 2     0022100002        NaN   0.61350      0.38650         0            0
# 3     0022100002        NaN   0.61348      0.38652         0            0
# 4     0022100002        NaN   0.61346      0.38654         0            0
# ...          ...        ...       ...          ...       ...          ...
# 3036  0022100002        NaN       NaN          NaN       114          121
# 3037  0022100002        NaN       NaN          NaN       114          121
# 3038  0022100002        NaN       NaN          NaN       114          121
# 3039  0022100002        NaN       NaN          NaN       114          121
# 3040  0022100002      724.0       NaN          NaN       114          121
#
#       HOME_SCORE_MARGIN  PERIOD  SECONDS_REMAINING  HOME_POSS_IND HOME_G  \
# 0                     0       1              720.0            NaN   None
# 1                     0       1              720.0            1.0   None
# 2                     0       1              719.0            1.0   None
# 3                     0       1              718.0            1.0   None
# 4                     0       1              717.0            1.0   None
# ...                 ...     ...                ...            ...    ...
# 3036                 -7       4                4.0            0.0   None
# 3037                 -7       4                3.0            0.0   None
# 3038                 -7       4                2.0            0.0   None
# 3039                 -7       4                1.0            0.0   None
# 3040                 -7       4                0.0            0.0   None
#
#                                     DESCRIPTION LOCATION PCTIMESTRING  \
# 0            Start of 1st Period (10:11 PM EST)                 12:00
# 1     Jump Ball Jordan vs. Looney: Tip to Davis        h        12:00
# 2                                          None     None         None
# 3                                          None     None         None
# 4                                          None     None         None
# ...                                         ...      ...          ...
# 3036                                       None     None         None
# 3037                                       None     None         None
# 3038                                       None     None         None
# 3039                                       None     None         None
# 3040           End of 4th Period (12:44 AM EST)                  0:00
#
#       ISVISIBLE
# 0           1.0
# 1           1.0
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 3036        NaN
# 3037        NaN
# 3038        NaN
# 3039        NaN
# 3040        1.0
#
# [3041 rows x 15 columns]

# %% [markdown]
# #### We started with the win_prob endpoint as this houses play-by-play by second/minutes.
# We need to then have a `absolute_time` in game seconds since the play started.

# %%
# Utilize user function to create absolute time (in seconds) column
df_base['abs_time'] = np.where(df_base.PERIOD <5,
                     ((df_base.PERIOD - 1) * 720 + (720 - df_base.SECONDS_REMAINING)),
                     (2880 + (df_base.PERIOD - 5) * 300 + (300 - df_base.SECONDS_REMAINING)))

# %% [markdown]
# ### Adding on the Rotation Dataframe so we can have each players' minutes of play vs rest times.

# %%
df_rotation = gamerotation.GameRotation(game_id).get_data_frames()

# %% [markdown]
# 'Game Rotation' returns all the minutes (play time in the court) for every player in the game, seperated into Home and Visitor Dataframes.  As such we search through players for the records with our player_id.  Returns a dataframe holding their rotational stats, most importantly in_time and out_time.

# %%
#for-loop to cycle through the players (by ID) in the rotation df
#to then grab their times:
for i in range(2):
    for player in df_rotation[i].PERSON_ID:
        if player == player_id:
            df_player_roto = df_rotation[i][df_rotation[i].PERSON_ID == player]

# %% [markdown]
# We need to convert the rotational time in 1/10ths of second, into seconds, then isolate those times out.

# %%
df_player_roto['abs_in_time'] = df_player_roto.IN_TIME_REAL/10
df_player_roto['abs_out_time'] = df_player_roto.OUT_TIME_REAL/10
df_player_roto_times = df_player_roto[['abs_in_time','abs_out_time']].reset_index(drop = 'True')

# %% [markdown]
# Using a zip function, we are putting together the in and out times together.

# %%
zipped = list(zip(df_player_roto_times.abs_in_time, df_player_roto_times.abs_out_time))

# %%
#showing what it looks like now:
zipped
# Out:
# [(0.0, 720.0), (1108.0, 2160.0), (2481.0, 2880.0)]

# %% [markdown]
# #### Let's filter out the times of the game (from the df_base of  win_prob) that align with the player's play time.

# %%
# Let me create a holder dataframe as I pull slices off from the base
df_player_game = pd.DataFrame()
for tuplez in zipped:
    df_slice = df_base[(df_base.abs_time >= tuplez[0]) & (df_base.abs_time <= tuplez[1])]
    df_player_game = pd.concat([df_player_game, df_slice])
df_player_game
# Out:
#          GAME_ID  EVENT_NUM  HOME_PCT  VISITOR_PCT  HOME_PTS  VISITOR_PTS  \
# 0     0022100002        2.0   0.58808      0.41192         0            0
# 1     0022100002        4.0   0.61352      0.38648         0            0
# 2     0022100002        NaN   0.61350      0.38650         0            0
# 3     0022100002        NaN   0.61348      0.38652         0            0
# 4     0022100002        NaN   0.61346      0.38654         0            0
# ...          ...        ...       ...          ...       ...          ...
# 3036  0022100002        NaN       NaN          NaN       114          121
# 3037  0022100002        NaN       NaN          NaN       114          121
# 3038  0022100002        NaN       NaN          NaN       114          121
# 3039  0022100002        NaN       NaN          NaN       114          121
# 3040  0022100002      724.0       NaN          NaN       114          121
#
#       HOME_SCORE_MARGIN  PERIOD  SECONDS_REMAINING  HOME_POSS_IND HOME_G  \
# 0                     0       1              720.0            NaN   None
# 1                     0       1              720.0            1.0   None
# 2                     0       1              719.0            1.0   None
# 3                     0       1              718.0            1.0   None
# 4                     0       1              717.0            1.0   None
# ...                 ...     ...                ...            ...    ...
# 3036                 -7       4                4.0            0.0   None
# 3037                 -7       4                3.0            0.0   None
# 3038                 -7       4                2.0            0.0   None
# 3039                 -7       4                1.0            0.0   None
# 3040                 -7       4                0.0            0.0   None
#
#                                     DESCRIPTION LOCATION PCTIMESTRING  \
# 0            Start of 1st Period (10:11 PM EST)                 12:00
# 1     Jump Ball Jordan vs. Looney: Tip to Davis        h        12:00
# 2                                          None     None         None
# 3                                          None     None         None
# 4                                          None     None         None
# ...                                         ...      ...          ...
# 3036                                       None     None         None
# 3037                                       None     None         None
# 3038                                       None     None         None
# 3039                                       None     None         None
# 3040           End of 4th Period (12:44 AM EST)                  0:00
#
#       ISVISIBLE  abs_time
# 0           1.0       0.0
# 1           1.0       0.0
# 2           NaN       1.0
# 3           NaN       2.0
# 4           NaN       3.0
# ...         ...       ...
# 3036        NaN    2876.0
# 3037        NaN    2877.0
# 3038        NaN    2878.0
# 3039        NaN    2879.0
# 3040        1.0    2880.0
#
# [2303 rows x 16 columns]

# %%
#testing this out:
df_test = df_player_game.copy()
df_test
# Out:
#          GAME_ID  EVENT_NUM  HOME_PCT  VISITOR_PCT  HOME_PTS  VISITOR_PTS  \
# 0     0022100002        2.0   0.58808      0.41192         0            0
# 1     0022100002        4.0   0.61352      0.38648         0            0
# 2     0022100002        NaN   0.61350      0.38650         0            0
# 3     0022100002        NaN   0.61348      0.38652         0            0
# 4     0022100002        NaN   0.61346      0.38654         0            0
# ...          ...        ...       ...          ...       ...          ...
# 3036  0022100002        NaN       NaN          NaN       114          121
# 3037  0022100002        NaN       NaN          NaN       114          121
# 3038  0022100002        NaN       NaN          NaN       114          121
# 3039  0022100002        NaN       NaN          NaN       114          121
# 3040  0022100002      724.0       NaN          NaN       114          121
#
#       HOME_SCORE_MARGIN  PERIOD  SECONDS_REMAINING  HOME_POSS_IND HOME_G  \
# 0                     0       1              720.0            NaN   None
# 1                     0       1              720.0            1.0   None
# 2                     0       1              719.0            1.0   None
# 3                     0       1              718.0            1.0   None
# 4                     0       1              717.0            1.0   None
# ...                 ...     ...                ...            ...    ...
# 3036                 -7       4                4.0            0.0   None
# 3037                 -7       4                3.0            0.0   None
# 3038                 -7       4                2.0            0.0   None
# 3039                 -7       4                1.0            0.0   None
# 3040                 -7       4                0.0            0.0   None
#
#                                     DESCRIPTION LOCATION PCTIMESTRING  \
# 0            Start of 1st Period (10:11 PM EST)                 12:00
# 1     Jump Ball Jordan vs. Looney: Tip to Davis        h        12:00
# 2                                          None     None         None
# 3                                          None     None         None
# 4                                          None     None         None
# ...                                         ...      ...          ...
# 3036                                       None     None         None
# 3037                                       None     None         None
# 3038                                       None     None         None
# 3039                                       None     None         None
# 3040           End of 4th Period (12:44 AM EST)                  0:00
#
#       ISVISIBLE  abs_time
# 0           1.0       0.0
# 1           1.0       0.0
# 2           NaN       1.0
# 3           NaN       2.0
# 4           NaN       3.0
# ...         ...       ...
# 3036        NaN    2876.0
# 3037        NaN    2877.0
# 3038        NaN    2878.0
# 3039        NaN    2879.0
# 3040        1.0    2880.0
#
# [2303 rows x 16 columns]

# %%
df_player_game.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2303 entries, 0 to 3040
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GAME_ID            2303 non-null   object
#  1   EVENT_NUM          406 non-null    float64
#  2   HOME_PCT           1986 non-null   float64
#  3   VISITOR_PCT        1986 non-null   float64
#  4   HOME_PTS           2303 non-null   int64
#  5   VISITOR_PTS        2303 non-null   int64
#  6   HOME_SCORE_MARGIN  2303 non-null   int64
#  7   PERIOD             2303 non-null   int64
#  8   SECONDS_REMAINING  2303 non-null   float64
#  9   HOME_POSS_IND      2302 non-null   float64
#  10  HOME_G             0 non-null      object
#  11  DESCRIPTION        406 non-null    object
#  12  LOCATION           406 non-null    object
#  13  PCTIMESTRING       406 non-null    object
#  14  ISVISIBLE          406 non-null    float64
#  15  abs_time           2303 non-null   float64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 305.9+ KB

# %%
df_player_game.EVENT_NUM
# Out:
# 0         2.0
# 1         4.0
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 3036      NaN
# 3037      NaN
# 3038      NaN
# 3039      NaN
# 3040    724.0
# Name: EVENT_NUM, Length: 2303, dtype: float64

# %%
#changing GAME_ID to numeric to later add on shot details df:
df_player_game.GAME_ID=pd.to_numeric(df_player_game.GAME_ID)

# %%
#checking the dtypes
df_player_game.dtypes
# Out:
# GAME_ID                int64
# EVENT_NUM            float64
# HOME_PCT             float64
# VISITOR_PCT          float64
# HOME_PTS               int64
# VISITOR_PTS            int64
# HOME_SCORE_MARGIN      int64
# PERIOD                 int64
# SECONDS_REMAINING    float64
# HOME_POSS_IND        float64
# HOME_G                object
# DESCRIPTION           object
# LOCATION              object
# PCTIMESTRING          object
# ISVISIBLE            float64
# abs_time             float64
# dtype: object

# %% [markdown]
# ### Creating Shot Details df:

# %%
#using abs_time on main df to account for overtime, and then calculates that overtime a bit different than regular 
#period plays
#plus the minutes - seconds remaining
df_shots['abs_time'] = np.where(df_shots.PERIOD < 5,
                                (df_shots.PERIOD - 1) * 720 + (720 - (60 * df_shots.MINUTES_REMAINING) - (df_shots.SECONDS_REMAINING)),
                                2880 + ((df_shots.PERIOD - 5) * 300) + (300 - (60 * df_shots.MINUTES_REMAINING) - (df_shots.SECONDS_REMAINING)))

# %%
#setting up GAME_ID for this df to be int:
df_game_shots = df_shots[df_shots.GAME_ID == int(game_id)]

# %%
#changing the df PLAYER_ID (will change all to lower down below)
df_game_shots = df_game_shots[df_game_shots.PLAYER_ID == player_id]

# %%
#resetting the index here:/
df_game_shots.reset_index(drop = True)
# Out:
#             GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID    PLAYER_NAME  \
# 0   Shot Chart Detail  22100002             26     201939  Stephen Curry
# 1   Shot Chart Detail  22100002             34     201939  Stephen Curry
# 2   Shot Chart Detail  22100002             37     201939  Stephen Curry
# 3   Shot Chart Detail  22100002             75     201939  Stephen Curry
# 4   Shot Chart Detail  22100002            130     201939  Stephen Curry
# 5   Shot Chart Detail  22100002            139     201939  Stephen Curry
# 6   Shot Chart Detail  22100002            176     201939  Stephen Curry
# 7   Shot Chart Detail  22100002            179     201939  Stephen Curry
# 8   Shot Chart Detail  22100002            323     201939  Stephen Curry
# 9   Shot Chart Detail  22100002            352     201939  Stephen Curry
# 10  Shot Chart Detail  22100002            368     201939  Stephen Curry
# 11  Shot Chart Detail  22100002            379     201939  Stephen Curry
# 12  Shot Chart Detail  22100002            427     201939  Stephen Curry
# 13  Shot Chart Detail  22100002            463     201939  Stephen Curry
# 14  Shot Chart Detail  22100002            496     201939  Stephen Curry
# 15  Shot Chart Detail  22100002            506     201939  Stephen Curry
# 16  Shot Chart Detail  22100002            510     201939  Stephen Curry
# 17  Shot Chart Detail  22100002            520     201939  Stephen Curry
# 18  Shot Chart Detail  22100002            642     201939  Stephen Curry
# 19  Shot Chart Detail  22100002            682     201939  Stephen Curry
# 20  Shot Chart Detail  22100002            693     201939  Stephen Curry
#
#        TEAM_ID              TEAM_NAME  PERIOD  MINUTES_REMAINING  \
# 0   1610612744  Golden State Warriors       1                 10
# 1   1610612744  Golden State Warriors       1                  9
# 2   1610612744  Golden State Warriors       1                  9
# 3   1610612744  Golden State Warriors       1                  6
# 4   1610612744  Golden State Warriors       1                  3
# 5   1610612744  Golden State Warriors       1                  2
# 6   1610612744  Golden State Warriors       1                  0
# 7   1610612744  Golden State Warriors       1                  0
# 8   1610612744  Golden State Warriors       2                  2
# 9   1610612744  Golden State Warriors       2                  1
# 10  1610612744  Golden State Warriors       2                  0
# 11  1610612744  Golden State Warriors       3                 11
# 12  1610612744  Golden State Warriors       3                  8
# 13  1610612744  Golden State Warriors       3                  6
# 14  1610612744  Golden State Warriors       3                  3
# 15  1610612744  Golden State Warriors       3                  2
# 16  1610612744  Golden State Warriors       3                  2
# 17  1610612744  Golden State Warriors       3                  1
# 18  1610612744  Golden State Warriors       4                  5
# 19  1610612744  Golden State Warriors       4                  2
# 20  1610612744  Golden State Warriors       4                  1
#
#     SECONDS_REMAINING   EVENT_TYPE                     ACTION_TYPE  \
# 0                   9  Missed Shot                Pullup Jump shot
# 1                  41  Missed Shot       Running Pull-Up Jump Shot
# 2                  10    Made Shot                       Jump Shot
# 3                  17  Missed Shot  Driving Finger Roll Layup Shot
# 4                  11  Missed Shot                      Layup Shot
# 5                  25  Missed Shot              Driving Layup Shot
# 6                  27    Made Shot  Driving Finger Roll Layup Shot
# 7                   1  Missed Shot       Running Pull-Up Jump Shot
# 8                  47  Missed Shot              Running Layup Shot
# 9                  29    Made Shot                      Layup Shot
# 10                  2  Missed Shot              Driving Layup Shot
# 11                 41  Missed Shot              Floating Jump shot
# 12                 23  Missed Shot             Step Back Jump shot
# 13                 10  Missed Shot                       Jump Shot
# 14                 38  Missed Shot                       Jump Shot
# 15                 42  Missed Shot              Floating Jump shot
# 16                 23    Made Shot              Cutting Layup Shot
# 17                 46  Missed Shot                      Layup Shot
# 18                 34    Made Shot                       Jump Shot
# 19                  7  Missed Shot             Step Back Jump shot
# 20                  5  Missed Shot                Pullup Jump shot
#
#          SHOT_TYPE        SHOT_ZONE_BASIC         SHOT_ZONE_AREA  \
# 0   3PT Field Goal      Above the Break 3   Left Side Center(LC)
# 1   3PT Field Goal      Above the Break 3              Center(C)
# 2   3PT Field Goal      Above the Break 3   Left Side Center(LC)
# 3   2PT Field Goal        Restricted Area              Center(C)
# 4   2PT Field Goal        Restricted Area              Center(C)
# 5   2PT Field Goal        Restricted Area              Center(C)
# 6   2PT Field Goal        Restricted Area              Center(C)
# 7   3PT Field Goal      Above the Break 3  Right Side Center(RC)
# 8   2PT Field Goal        Restricted Area              Center(C)
# 9   2PT Field Goal        Restricted Area              Center(C)
# 10  2PT Field Goal        Restricted Area              Center(C)
# 11  2PT Field Goal  In The Paint (Non-RA)              Center(C)
# 12  3PT Field Goal          Left Corner 3           Left Side(L)
# 13  3PT Field Goal      Above the Break 3   Left Side Center(LC)
# 14  3PT Field Goal          Left Corner 3           Left Side(L)
# 15  2PT Field Goal  In The Paint (Non-RA)              Center(C)
# 16  2PT Field Goal        Restricted Area              Center(C)
# 17  2PT Field Goal        Restricted Area              Center(C)
# 18  3PT Field Goal      Above the Break 3              Center(C)
# 19  2PT Field Goal              Mid-Range           Left Side(L)
# 20  2PT Field Goal              Mid-Range   Left Side Center(LC)
#
#     SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  SHOT_ATTEMPTED_FLAG  \
# 0           24+ ft.             28   -109    260                    1
# 1           24+ ft.             26     48    257                    1
# 2           24+ ft.             25   -165    189                    1
# 3   Less Than 8 ft.              1    -13     12                    1
# 4   Less Than 8 ft.              2    -15     22                    1
# 5   Less Than 8 ft.              2     18     16                    1
# 6   Less Than 8 ft.              2     -7     29                    1
# 7           24+ ft.             26    135    228                    1
# 8   Less Than 8 ft.              2     -9     18                    1
# 9   Less Than 8 ft.              1     -1     10                    1
# 10  Less Than 8 ft.              2     -1     22                    1
# 11         8-16 ft.             14     66    130                    1
# 12          24+ ft.             23   -238     11                    1
# 13          24+ ft.             26    -89    247                    1
# 14          24+ ft.             23   -230      6                    1
# 15  Less Than 8 ft.              4      4     41                    1
# 16  Less Than 8 ft.              1      7      8                    1
# 17  Less Than 8 ft.              2      7     21                    1
# 18          24+ ft.             26     48    260                    1
# 19         8-16 ft.             14    -98    108                    1
# 20        16-24 ft.             16    -97    131                    1
#
#     SHOT_MADE_FLAG  GAME_DATE  HTM  VTM              location  abs_time
# 0                0   20211019  LAL  GSW              L Center       111
# 1                0   20211019  LAL  GSW              R Center       139
# 2                1   20211019  LAL  GSW         L Above Break       170
# 3                0   20211019  LAL  GSW                   NaN       343
# 4                0   20211019  LAL  GSW                   NaN       529
# 5                0   20211019  LAL  GSW                   NaN       575
# 6                1   20211019  LAL  GSW                   NaN       693
# 7                0   20211019  LAL  GSW         R Above Break       719
# 8                0   20211019  LAL  GSW                   NaN      1273
# 9                1   20211019  LAL  GSW                   NaN      1351
# 10               0   20211019  LAL  GSW                   NaN      1438
# 11               0   20211019  LAL  GSW                   NaN      1459
# 12               0   20211019  LAL  GSW  R Below Break/Corner      1657
# 13               0   20211019  LAL  GSW              L Center      1790
# 14               0   20211019  LAL  GSW  R Below Break/Corner      1942
# 15               0   20211019  LAL  GSW                   NaN      1998
# 16               1   20211019  LAL  GSW                   NaN      2017
# 17               0   20211019  LAL  GSW                   NaN      2054
# 18               1   20211019  LAL  GSW              R Center      2546
# 19               0   20211019  LAL  GSW                   NaN      2753
# 20               0   20211019  LAL  GSW                   NaN      2815

# %%
#getting the Spurs abbreviations- 
teams.find_teams_by_full_name(df_game_shots.TEAM_NAME.max())[0]['abbreviation']
# Out:
# 'GSW'

# %%
#combining home and visitor column with only the Spurs team
df_game_shots['player_h_v'] = np.where(teams.find_teams_by_full_name(df_game_shots.TEAM_NAME.max())[0]['abbreviation'] == df_game_shots.HTM, 'Home', 'Visitor')

# %% [markdown]
# ### Merging main_df with the Shot details df:

# %%
df_almostthere = df_player_game.merge(df_game_shots, how = 'inner', on = 'abs_time')

# %%
df_almostthere
# Out:
#     GAME_ID_x  EVENT_NUM  HOME_PCT  VISITOR_PCT  HOME_PTS  VISITOR_PTS  \
# 0    22100002       26.0   0.55387      0.44613         2            4
# 1    22100002       34.0   0.55231      0.44769         2            4
# 2    22100002       37.0   0.55980      0.44020         4            7
# 3    22100002       75.0   0.61909      0.38091        14           12
# 4    22100002      130.0   0.72275      0.27725        25           18
# 5    22100002      139.0   0.72624      0.27376        28           21
# 6    22100002      176.0   0.64726      0.35274        34           32
# 7    22100002      179.0   0.62293      0.37707        34           32
# 8    22100002      180.0   0.62293      0.37707        34           32
# 9    22100002      323.0   0.66126      0.33874        50           47
# 10   22100002      325.0   0.66126      0.33874        50           47
# 11   22100002      326.0   0.66126      0.33874        50           47
# 12   22100002      327.0   0.66126      0.33874        50           47
# 13   22100002      328.0   0.66126      0.33874        50           47
# 14   22100002      329.0   0.66126      0.33874        50           47
# 15   22100002      352.0   0.68647      0.31353        54           51
# 16   22100002      368.0   0.75931      0.24069        59           53
# 17   22100002      379.0   0.76050      0.23950        59           53
# 18   22100002      427.0   0.67071      0.32929        64           61
# 19   22100002      463.0   0.77880      0.22120        72           66
# 20   22100002      496.0   0.75369      0.24631        77           72
# 21   22100002      506.0   0.84639      0.15361        82           74
# 22   22100002      510.0   0.86071      0.13929        84           76
# 23   22100002      520.0   0.84961      0.15039        84           76
# 24   22100002      522.0   0.84961      0.15039        84           76
# 25   22100002      523.0   0.84961      0.15039        84           76
# 26   22100002      642.0   0.28691      0.71309        98          103
# 27   22100002      682.0       NaN          NaN       103          115
# 28   22100002      693.0       NaN          NaN       106          115
#
#     HOME_SCORE_MARGIN  PERIOD_x  SECONDS_REMAINING_x  HOME_POSS_IND HOME_G  \
# 0                  -2         1                609.0            0.0   None
# 1                  -2         1                581.0            0.0   None
# 2                  -3         1                550.0            1.0   None
# 3                   2         1                377.0            0.0   None
# 4                   7         1                191.0            0.0   None
# 5                   7         1                145.0            0.0   None
# 6                   2         1                 27.0            1.0   None
# 7                   2         1                  1.0            0.0   None
# 8                   2         1                  1.0            0.0   None
# 9                   3         2                167.0            0.0   None
# 10                  3         2                167.0            0.0   None
# 11                  3         2                167.0            0.0   None
# 12                  3         2                167.0            0.0   None
# 13                  3         2                167.0            0.0   None
# 14                  3         2                167.0            0.0   None
# 15                  3         2                 89.0            1.0   None
# 16                  6         2                  2.0            0.0   None
# 17                  6         3                701.0            0.0   None
# 18                  3         3                503.0            0.0   None
# 19                  6         3                370.0            0.0   None
# 20                  5         3                218.0            0.0   None
# 21                  8         3                162.0            0.0   None
# 22                  8         3                143.0            1.0   None
# 23                  8         3                106.0            0.0   None
# 24                  8         3                106.0            0.0   None
# 25                  8         3                106.0            0.0   None
# 26                 -5         4                334.0            1.0   None
# 27                -12         4                127.0            0.0   None
# 28                 -9         4                 65.0            0.0   None
#
#                                           DESCRIPTION LOCATION PCTIMESTRING  \
# 0                 MISS Curry 28' 3PT Pullup Jump Shot        v        10:09
# 1        MISS Curry 26' 3PT Running Pull-Up Jump Shot        v         9:41
# 2       Curry 25' 3PT Jump Shot (3 PTS) (Green 1 AST)        v         9:10
# 3   MISS Curry 2' Driving Finger Roll Layup#@#Davi...        v         6:17
# 4                                 MISS Curry 3' Layup        v         3:11
# 5                         MISS Curry 2' Driving Layup        v         2:25
# 6          Curry 3' Driving Finger Roll Layup (8 PTS)        v         0:27
# 7        MISS Curry 26' 3PT Running Pull-Up Jump Shot        v         0:01
# 8                                    Warriors Rebound        v         0:01
# 9   MISS Curry 2' Running Layup#@#Bazemore BLOCK (...        v         2:47
# 10                                   Warriors Rebound        v         2:47
# 11                                      Out-of-Bounds                  2:47
# 12                               SUB: James FOR Rondo        h         2:47
# 13                            SUB: Anthony FOR Howard        h         2:47
# 14                                 SUB: Lee FOR Moody        v         2:47
# 15                            Curry 1' Layup (10 PTS)        v         1:29
# 16                        MISS Curry 2' Driving Layup        v         0:02
# 17                  MISS Curry 15' Floating Jump Shot        v        11:41
# 18             MISS Curry 24' 3PT Step Back Jump Shot        v         8:23
# 19                       MISS Curry 26' 3PT Jump Shot        v         6:10
# 20                           MISS Curry 3PT Jump Shot        v         3:38
# 21                   MISS Curry 4' Floating Jump Shot        v         2:42
# 22  Curry 1' Cutting Layup Shot (13 PTS) (Iguodala...        v         2:23
# 23          MISS Curry 2' Layup#@#Davis BLOCK (2 BLK)        v         1:46
# 24                                   Warriors Rebound        v         1:46
# 25                                      Out-of-Bounds                  1:46
# 26                   Curry 26' 3PT Jump Shot (19 PTS)        v         5:34
# 27                 MISS Curry 15' Step Back Jump Shot        v         2:07
# 28                    MISS Curry 16' Pullup Jump Shot        v         1:05
#
#     ISVISIBLE  abs_time          GRID_TYPE  GAME_ID_y  GAME_EVENT_ID  \
# 0         1.0     111.0  Shot Chart Detail   22100002             26
# 1         1.0     139.0  Shot Chart Detail   22100002             34
# 2         1.0     170.0  Shot Chart Detail   22100002             37
# 3         1.0     343.0  Shot Chart Detail   22100002             75
# 4         1.0     529.0  Shot Chart Detail   22100002            130
# 5         1.0     575.0  Shot Chart Detail   22100002            139
# 6         1.0     693.0  Shot Chart Detail   22100002            176
# 7         1.0     719.0  Shot Chart Detail   22100002            179
# 8         1.0     719.0  Shot Chart Detail   22100002            179
# 9         1.0    1273.0  Shot Chart Detail   22100002            323
# 10        1.0    1273.0  Shot Chart Detail   22100002            323
# 11        0.0    1273.0  Shot Chart Detail   22100002            323
# 12        1.0    1273.0  Shot Chart Detail   22100002            323
# 13        1.0    1273.0  Shot Chart Detail   22100002            323
# 14        1.0    1273.0  Shot Chart Detail   22100002            323
# 15        1.0    1351.0  Shot Chart Detail   22100002            352
# 16        1.0    1438.0  Shot Chart Detail   22100002            368
# 17        1.0    1459.0  Shot Chart Detail   22100002            379
# 18        1.0    1657.0  Shot Chart Detail   22100002            427
# 19        1.0    1790.0  Shot Chart Detail   22100002            463
# 20        1.0    1942.0  Shot Chart Detail   22100002            496
# 21        1.0    1998.0  Shot Chart Detail   22100002            506
# 22        1.0    2017.0  Shot Chart Detail   22100002            510
# 23        1.0    2054.0  Shot Chart Detail   22100002            520
# 24        1.0    2054.0  Shot Chart Detail   22100002            520
# 25        0.0    2054.0  Shot Chart Detail   22100002            520
# 26        1.0    2546.0  Shot Chart Detail   22100002            642
# 27        1.0    2753.0  Shot Chart Detail   22100002            682
# 28        1.0    2815.0  Shot Chart Detail   22100002            693
#
#     PLAYER_ID    PLAYER_NAME     TEAM_ID              TEAM_NAME  PERIOD_y  \
# 0      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 1      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 2      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 3      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 4      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 5      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 6      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 7      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 8      201939  Stephen Curry  1610612744  Golden State Warriors         1
# 9      201939  Stephen Curry  1610612744  Golden State Warriors         2
# 10     201939  Stephen Curry  1610612744  Golden State Warriors         2
# 11     201939  Stephen Curry  1610612744  Golden State Warriors         2
# 12     201939  Stephen Curry  1610612744  Golden State Warriors         2
# 13     201939  Stephen Curry  1610612744  Golden State Warriors         2
# 14     201939  Stephen Curry  1610612744  Golden State Warriors         2
# 15     201939  Stephen Curry  1610612744  Golden State Warriors         2
# 16     201939  Stephen Curry  1610612744  Golden State Warriors         2
# 17     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 18     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 19     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 20     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 21     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 22     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 23     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 24     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 25     201939  Stephen Curry  1610612744  Golden State Warriors         3
# 26     201939  Stephen Curry  1610612744  Golden State Warriors         4
# 27     201939  Stephen Curry  1610612744  Golden State Warriors         4
# 28     201939  Stephen Curry  1610612744  Golden State Warriors         4
#
#     MINUTES_REMAINING  SECONDS_REMAINING_y   EVENT_TYPE  \
# 0                  10                    9  Missed Shot
# 1                   9                   41  Missed Shot
# 2                   9                   10    Made Shot
# 3                   6                   17  Missed Shot
# 4                   3                   11  Missed Shot
# 5                   2                   25  Missed Shot
# 6                   0                   27    Made Shot
# 7                   0                    1  Missed Shot
# 8                   0                    1  Missed Shot
# 9                   2                   47  Missed Shot
# 10                  2                   47  Missed Shot
# 11                  2                   47  Missed Shot
# 12                  2                   47  Missed Shot
# 13                  2                   47  Missed Shot
# 14                  2                   47  Missed Shot
# 15                  1                   29    Made Shot
# 16                  0                    2  Missed Shot
# 17                 11                   41  Missed Shot
# 18                  8                   23  Missed Shot
# 19                  6                   10  Missed Shot
# 20                  3                   38  Missed Shot
# 21                  2                   42  Missed Shot
# 22                  2                   23    Made Shot
# 23                  1                   46  Missed Shot
# 24                  1                   46  Missed Shot
# 25                  1                   46  Missed Shot
# 26                  5                   34    Made Shot
# 27                  2                    7  Missed Shot
# 28                  1                    5  Missed Shot
#
#                        ACTION_TYPE       SHOT_TYPE        SHOT_ZONE_BASIC  \
# 0                 Pullup Jump shot  3PT Field Goal      Above the Break 3
# 1        Running Pull-Up Jump Shot  3PT Field Goal      Above the Break 3
# 2                        Jump Shot  3PT Field Goal      Above the Break 3
# 3   Driving Finger Roll Layup Shot  2PT Field Goal        Restricted Area
# 4                       Layup Shot  2PT Field Goal        Restricted Area
# 5               Driving Layup Shot  2PT Field Goal        Restricted Area
# 6   Driving Finger Roll Layup Shot  2PT Field Goal        Restricted Area
# 7        Running Pull-Up Jump Shot  3PT Field Goal      Above the Break 3
# 8        Running Pull-Up Jump Shot  3PT Field Goal      Above the Break 3
# 9               Running Layup Shot  2PT Field Goal        Restricted Area
# 10              Running Layup Shot  2PT Field Goal        Restricted Area
# 11              Running Layup Shot  2PT Field Goal        Restricted Area
# 12              Running Layup Shot  2PT Field Goal        Restricted Area
# 13              Running Layup Shot  2PT Field Goal        Restricted Area
# 14              Running Layup Shot  2PT Field Goal        Restricted Area
# 15                      Layup Shot  2PT Field Goal        Restricted Area
# 16              Driving Layup Shot  2PT Field Goal        Restricted Area
# 17              Floating Jump shot  2PT Field Goal  In The Paint (Non-RA)
# 18             Step Back Jump shot  3PT Field Goal          Left Corner 3
# 19                       Jump Shot  3PT Field Goal      Above the Break 3
# 20                       Jump Shot  3PT Field Goal          Left Corner 3
# 21              Floating Jump shot  2PT Field Goal  In The Paint (Non-RA)
# 22              Cutting Layup Shot  2PT Field Goal        Restricted Area
# 23                      Layup Shot  2PT Field Goal        Restricted Area
# 24                      Layup Shot  2PT Field Goal        Restricted Area
# 25                      Layup Shot  2PT Field Goal        Restricted Area
# 26                       Jump Shot  3PT Field Goal      Above the Break 3
# 27             Step Back Jump shot  2PT Field Goal              Mid-Range
# 28                Pullup Jump shot  2PT Field Goal              Mid-Range
#
#            SHOT_ZONE_AREA  SHOT_ZONE_RANGE  SHOT_DISTANCE  LOC_X  LOC_Y  \
# 0    Left Side Center(LC)          24+ ft.             28   -109    260
# 1               Center(C)          24+ ft.             26     48    257
# 2    Left Side Center(LC)          24+ ft.             25   -165    189
# 3               Center(C)  Less Than 8 ft.              1    -13     12
# 4               Center(C)  Less Than 8 ft.              2    -15     22
# 5               Center(C)  Less Than 8 ft.              2     18     16
# 6               Center(C)  Less Than 8 ft.              2     -7     29
# 7   Right Side Center(RC)          24+ ft.             26    135    228
# 8   Right Side Center(RC)          24+ ft.             26    135    228
# 9               Center(C)  Less Than 8 ft.              2     -9     18
# 10              Center(C)  Less Than 8 ft.              2     -9     18
# 11              Center(C)  Less Than 8 ft.              2     -9     18
# 12              Center(C)  Less Than 8 ft.              2     -9     18
# 13              Center(C)  Less Than 8 ft.              2     -9     18
# 14              Center(C)  Less Than 8 ft.              2     -9     18
# 15              Center(C)  Less Than 8 ft.              1     -1     10
# 16              Center(C)  Less Than 8 ft.              2     -1     22
# 17              Center(C)         8-16 ft.             14     66    130
# 18           Left Side(L)          24+ ft.             23   -238     11
# 19   Left Side Center(LC)          24+ ft.             26    -89    247
# 20           Left Side(L)          24+ ft.             23   -230      6
# 21              Center(C)  Less Than 8 ft.              4      4     41
# 22              Center(C)  Less Than 8 ft.              1      7      8
# 23              Center(C)  Less Than 8 ft.              2      7     21
# 24              Center(C)  Less Than 8 ft.              2      7     21
# 25              Center(C)  Less Than 8 ft.              2      7     21
# 26              Center(C)          24+ ft.             26     48    260
# 27           Left Side(L)         8-16 ft.             14    -98    108
# 28   Left Side Center(LC)        16-24 ft.             16    -97    131
#
#     SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG  GAME_DATE  HTM  VTM  \
# 0                     1               0   20211019  LAL  GSW
# 1                     1               0   20211019  LAL  GSW
# 2                     1               1   20211019  LAL  GSW
# 3                     1               0   20211019  LAL  GSW
# 4                     1               0   20211019  LAL  GSW
# 5                     1               0   20211019  LAL  GSW
# 6                     1               1   20211019  LAL  GSW
# 7                     1               0   20211019  LAL  GSW
# 8                     1               0   20211019  LAL  GSW
# 9                     1               0   20211019  LAL  GSW
# 10                    1               0   20211019  LAL  GSW
# 11                    1               0   20211019  LAL  GSW
# 12                    1               0   20211019  LAL  GSW
# 13                    1               0   20211019  LAL  GSW
# 14                    1               0   20211019  LAL  GSW
# 15                    1               1   20211019  LAL  GSW
# 16                    1               0   20211019  LAL  GSW
# 17                    1               0   20211019  LAL  GSW
# 18                    1               0   20211019  LAL  GSW
# 19                    1               0   20211019  LAL  GSW
# 20                    1               0   20211019  LAL  GSW
# 21                    1               0   20211019  LAL  GSW
# 22                    1               1   20211019  LAL  GSW
# 23                    1               0   20211019  LAL  GSW
# 24                    1               0   20211019  LAL  GSW
# 25                    1               0   20211019  LAL  GSW
# 26                    1               1   20211019  LAL  GSW
# 27                    1               0   20211019  LAL  GSW
# 28                    1               0   20211019  LAL  GSW
#
#                 location player_h_v
# 0               L Center    Visitor
# 1               R Center    Visitor
# 2          L Above Break    Visitor
# 3                    NaN    Visitor
# 4                    NaN    Visitor
# 5                    NaN    Visitor
# 6                    NaN    Visitor
# 7          R Above Break    Visitor
# 8          R Above Break    Visitor
# 9                    NaN    Visitor
# 10                   NaN    Visitor
# 11                   NaN    Visitor
# 12                   NaN    Visitor
# 13                   NaN    Visitor
# 14                   NaN    Visitor
# 15                   NaN    Visitor
# 16                   NaN    Visitor
# 17                   NaN    Visitor
# 18  R Below Break/Corner    Visitor
# 19              L Center    Visitor
# 20  R Below Break/Corner    Visitor
# 21                   NaN    Visitor
# 22                   NaN    Visitor
# 23                   NaN    Visitor
# 24                   NaN    Visitor
# 25                   NaN    Visitor
# 26              R Center    Visitor
# 27                   NaN    Visitor
# 28                   NaN    Visitor

# %%
#adding in the column score_margin that holds the home score margins:
df_almostthere['score_margin'] = np.where(df_almostthere.player_h_v == 'Home', df_almostthere.HOME_SCORE_MARGIN, df_almostthere.HOME_SCORE_MARGIN * -1)

# %%
#since we get two columns for every game (Home vs Visitor)
#we want to drop and only hold the Spurs with whichever
#they are (H or V) and only show those win percentages:

if df_almostthere.loc[0,'player_h_v'] == 'Home':
    df_almostthere = df_almostthere.drop(columns = ['VISITOR_PCT'])
    df_almostthere = df_almostthere.rename(columns = {'HOME_PCT':"WIN_PCT"})
else:
    df_almostthere = df_almostthere.drop(columns = ['HOME_PCT'])
    df_almostthere = df_almostthere.rename(columns = {'VISITOR_PCT':"WIN_PCT"})

# %%
#creating a column `play_points` that 
df_almostthere['play_points'] = np.where(df_almostthere.SHOT_TYPE == '2PT Field Goal',
                                    np.where(df_almostthere.SHOT_MADE_FLAG == 1, 2,0),
                                    np.where(df_almostthere.SHOT_MADE_FLAG == 1, 3,0))

# %%
df_almostthere['points'] = df_almostthere['play_points'].cumsum()

# %%
df_almostthere['shots_taken'] = df_almostthere['SHOT_ATTEMPTED_FLAG'].cumsum()
df_almostthere['shots_hit'] = df_almostthere['SHOT_MADE_FLAG'].cumsum()
df_almostthere['game_pct'] = round(df_almostthere['shots_hit']/df_almostthere['shots_taken'],2)

# %%
df_almostthere.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 0 to 28
# Data columns (total 47 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GAME_ID_x            29 non-null     int64
#  1   EVENT_NUM            29 non-null     float64
#  2   WIN_PCT              27 non-null     float64
#  3   HOME_PTS             29 non-null     int64
#  4   VISITOR_PTS          29 non-null     int64
#  5   HOME_SCORE_MARGIN    29 non-null     int64
#  6   PERIOD_x             29 non-null     int64
#  7   SECONDS_REMAINING_x  29 non-null     float64
#  8   HOME_POSS_IND        29 non-null     float64
#  9   HOME_G               0 non-null      object
#  10  DESCRIPTION          29 non-null     object
#  11  LOCATION             29 non-null     object
#  12  PCTIMESTRING         29 non-null     object
#  13  ISVISIBLE            29 non-null     float64
#  14  abs_time             29 non-null     float64
#  15  GRID_TYPE            29 non-null     object
#  16  GAME_ID_y            29 non-null     int64
#  17  GAME_EVENT_ID        29 non-null     int64
#  18  PLAYER_ID            29 non-null     int64
#  19  PLAYER_NAME          29 non-null     object
#  20  TEAM_ID              29 non-null     int64
#  21  TEAM_NAME            29 non-null     object
#  22  PERIOD_y             29 non-null     int64
#  23  MINUTES_REMAINING    29 non-null     int64
#  24  SECONDS_REMAINING_y  29 non-null     int64
#  25  EVENT_TYPE           29 non-null     object
#  26  ACTION_TYPE          29 non-null     object
#  27  SHOT_TYPE            29 non-null     object
#  28  SHOT_ZONE_BASIC      29 non-null     object
#  29  SHOT_ZONE_AREA       29 non-null     object
#  30  SHOT_ZONE_RANGE      29 non-null     object
#  31  SHOT_DISTANCE        29 non-null     int64
#  32  LOC_X                29 non-null     int64
#  33  LOC_Y                29 non-null     int64
#  34  SHOT_ATTEMPTED_FLAG  29 non-null     int64
#  35  SHOT_MADE_FLAG       29 non-null     int64
#  36  GAME_DATE            29 non-null     int64
#  37  HTM                  29 non-null     object
#  38  VTM                  29 non-null     object
#  39  location             9 non-null      object
#  40  player_h_v           29 non-null     object
#  41  score_margin         29 non-null     int64
#  42  play_points          29 non-null     int64
#  43  points               29 non-null     int64
#  44  shots_taken          29 non-null     int64
#  45  shots_hit            29 non-null     int64
#  46  game_pct             29 non-null     float64
# dtypes: float64(7), int64(23), object(17)
# memory usage: 11.9+ KB

# %%
columns_to_drop = [
    'GAME_ID_x',
    'EVENT_NUM',
    'HOME_PTS',
    'VISITOR_PTS',
    'HOME_SCORE_MARGIN',
    'PERIOD_x',
    'SECONDS_REMAINING_x',
    'HOME_POSS_IND',
    'HOME_G',
    'LOCATION',
    'PCTIMESTRING',
    'ISVISIBLE',
    'GRID_TYPE',
    'GAME_EVENT_ID',
    'MINUTES_REMAINING',
    'SECONDS_REMAINING_y',
    'SHOT_ZONE_BASIC',
    'SHOT_ZONE_AREA',
    'SHOT_ZONE_RANGE',
    'SHOT_ATTEMPTED_FLAG',
    'SHOT_MADE_FLAG',
    'GAME_DATE',
    'HTM',
    'VTM']

# %%
df_almostthere = df_almostthere.drop(columns = columns_to_drop)

# %%
df_almostthere
# Out:
#     WIN_PCT                                        DESCRIPTION  abs_time  \
# 0   0.44613                MISS Curry 28' 3PT Pullup Jump Shot     111.0
# 1   0.44769       MISS Curry 26' 3PT Running Pull-Up Jump Shot     139.0
# 2   0.44020      Curry 25' 3PT Jump Shot (3 PTS) (Green 1 AST)     170.0
# 3   0.38091  MISS Curry 2' Driving Finger Roll Layup#@#Davi...     343.0
# 4   0.27725                                MISS Curry 3' Layup     529.0
# 5   0.27376                        MISS Curry 2' Driving Layup     575.0
# 6   0.35274         Curry 3' Driving Finger Roll Layup (8 PTS)     693.0
# 7   0.37707       MISS Curry 26' 3PT Running Pull-Up Jump Shot     719.0
# 8   0.37707                                   Warriors Rebound     719.0
# 9   0.33874  MISS Curry 2' Running Layup#@#Bazemore BLOCK (...    1273.0
# 10  0.33874                                   Warriors Rebound    1273.0
# 11  0.33874                                      Out-of-Bounds    1273.0
# 12  0.33874                               SUB: James FOR Rondo    1273.0
# 13  0.33874                            SUB: Anthony FOR Howard    1273.0
# 14  0.33874                                 SUB: Lee FOR Moody    1273.0
# 15  0.31353                            Curry 1' Layup (10 PTS)    1351.0
# 16  0.24069                        MISS Curry 2' Driving Layup    1438.0
# 17  0.23950                  MISS Curry 15' Floating Jump Shot    1459.0
# 18  0.32929             MISS Curry 24' 3PT Step Back Jump Shot    1657.0
# 19  0.22120                       MISS Curry 26' 3PT Jump Shot    1790.0
# 20  0.24631                           MISS Curry 3PT Jump Shot    1942.0
# 21  0.15361                   MISS Curry 4' Floating Jump Shot    1998.0
# 22  0.13929  Curry 1' Cutting Layup Shot (13 PTS) (Iguodala...    2017.0
# 23  0.15039          MISS Curry 2' Layup#@#Davis BLOCK (2 BLK)    2054.0
# 24  0.15039                                   Warriors Rebound    2054.0
# 25  0.15039                                      Out-of-Bounds    2054.0
# 26  0.71309                   Curry 26' 3PT Jump Shot (19 PTS)    2546.0
# 27      NaN                 MISS Curry 15' Step Back Jump Shot    2753.0
# 28      NaN                    MISS Curry 16' Pullup Jump Shot    2815.0
#
#     GAME_ID_y  PLAYER_ID    PLAYER_NAME     TEAM_ID              TEAM_NAME  \
# 0    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 1    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 2    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 3    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 4    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 5    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 6    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 7    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 8    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 9    22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 10   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 11   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 12   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 13   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 14   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 15   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 16   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 17   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 18   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 19   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 20   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 21   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 22   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 23   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 24   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 25   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 26   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 27   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
# 28   22100002     201939  Stephen Curry  1610612744  Golden State Warriors
#
#     PERIOD_y   EVENT_TYPE                     ACTION_TYPE       SHOT_TYPE  \
# 0          1  Missed Shot                Pullup Jump shot  3PT Field Goal
# 1          1  Missed Shot       Running Pull-Up Jump Shot  3PT Field Goal
# 2          1    Made Shot                       Jump Shot  3PT Field Goal
# 3          1  Missed Shot  Driving Finger Roll Layup Shot  2PT Field Goal
# 4          1  Missed Shot                      Layup Shot  2PT Field Goal
# 5          1  Missed Shot              Driving Layup Shot  2PT Field Goal
# 6          1    Made Shot  Driving Finger Roll Layup Shot  2PT Field Goal
# 7          1  Missed Shot       Running Pull-Up Jump Shot  3PT Field Goal
# 8          1  Missed Shot       Running Pull-Up Jump Shot  3PT Field Goal
# 9          2  Missed Shot              Running Layup Shot  2PT Field Goal
# 10         2  Missed Shot              Running Layup Shot  2PT Field Goal
# 11         2  Missed Shot              Running Layup Shot  2PT Field Goal
# 12         2  Missed Shot              Running Layup Shot  2PT Field Goal
# 13         2  Missed Shot              Running Layup Shot  2PT Field Goal
# 14         2  Missed Shot              Running Layup Shot  2PT Field Goal
# 15         2    Made Shot                      Layup Shot  2PT Field Goal
# 16         2  Missed Shot              Driving Layup Shot  2PT Field Goal
# 17         3  Missed Shot              Floating Jump shot  2PT Field Goal
# 18         3  Missed Shot             Step Back Jump shot  3PT Field Goal
# 19         3  Missed Shot                       Jump Shot  3PT Field Goal
# 20         3  Missed Shot                       Jump Shot  3PT Field Goal
# 21         3  Missed Shot              Floating Jump shot  2PT Field Goal
# 22         3    Made Shot              Cutting Layup Shot  2PT Field Goal
# 23         3  Missed Shot                      Layup Shot  2PT Field Goal
# 24         3  Missed Shot                      Layup Shot  2PT Field Goal
# 25         3  Missed Shot                      Layup Shot  2PT Field Goal
# 26         4    Made Shot                       Jump Shot  3PT Field Goal
# 27         4  Missed Shot             Step Back Jump shot  2PT Field Goal
# 28         4  Missed Shot                Pullup Jump shot  2PT Field Goal
#
#     SHOT_DISTANCE  LOC_X  LOC_Y              location player_h_v  \
# 0              28   -109    260              L Center    Visitor
# 1              26     48    257              R Center    Visitor
# 2              25   -165    189         L Above Break    Visitor
# 3               1    -13     12                   NaN    Visitor
# 4               2    -15     22                   NaN    Visitor
# 5               2     18     16                   NaN    Visitor
# 6               2     -7     29                   NaN    Visitor
# 7              26    135    228         R Above Break    Visitor
# 8              26    135    228         R Above Break    Visitor
# 9               2     -9     18                   NaN    Visitor
# 10              2     -9     18                   NaN    Visitor
# 11              2     -9     18                   NaN    Visitor
# 12              2     -9     18                   NaN    Visitor
# 13              2     -9     18                   NaN    Visitor
# 14              2     -9     18                   NaN    Visitor
# 15              1     -1     10                   NaN    Visitor
# 16              2     -1     22                   NaN    Visitor
# 17             14     66    130                   NaN    Visitor
# 18             23   -238     11  R Below Break/Corner    Visitor
# 19             26    -89    247              L Center    Visitor
# 20             23   -230      6  R Below Break/Corner    Visitor
# 21              4      4     41                   NaN    Visitor
# 22              1      7      8                   NaN    Visitor
# 23              2      7     21                   NaN    Visitor
# 24              2      7     21                   NaN    Visitor
# 25              2      7     21                   NaN    Visitor
# 26             26     48    260              R Center    Visitor
# 27             14    -98    108                   NaN    Visitor
# 28             16    -97    131                   NaN    Visitor
#
#     score_margin  play_points  points  shots_taken  shots_hit  game_pct
# 0              2            0       0            1          0      0.00
# 1              2            0       0            2          0      0.00
# 2              3            3       3            3          1      0.33
# 3             -2            0       3            4          1      0.25
# 4             -7            0       3            5          1      0.20
# 5             -7            0       3            6          1      0.17
# 6             -2            2       5            7          2      0.29
# 7             -2            0       5            8          2      0.25
# 8             -2            0       5            9          2      0.22
# 9             -3            0       5           10          2      0.20
# 10            -3            0       5           11          2      0.18
# 11            -3            0       5           12          2      0.17
# 12            -3            0       5           13          2      0.15
# 13            -3            0       5           14          2      0.14
# 14            -3            0       5           15          2      0.13
# 15            -3            2       7           16          3      0.19
# 16            -6            0       7           17          3      0.18
# 17            -6            0       7           18          3      0.17
# 18            -3            0       7           19          3      0.16
# 19            -6            0       7           20          3      0.15
# 20            -5            0       7           21          3      0.14
# 21            -8            0       7           22          3      0.14
# 22            -8            2       9           23          4      0.17
# 23            -8            0       9           24          4      0.17
# 24            -8            0       9           25          4      0.16
# 25            -8            0       9           26          4      0.15
# 26             5            3      12           27          5      0.19
# 27            12            0      12           28          5      0.18
# 28             9            0      12           29          5      0.17

# %%
columns_to_rename = {'WIN_PCT':'win_probability',
                     'DESCRIPTION':'play_description',
                     'GAME_ID_y':'game_id',
                     'PLAYER_ID':'player_id',
                     'PLAYER_NAME':'player',
                     'TEAM_ID':'team_id',
                     'TEAM_NAME':'team',
                     'PERIOD_y':'period',
                     'EVENT_TYPE': 'shot_result',
                     'ACTION_TYPE':'shot_type',
                     'SHOT_TYPE':'field_goal',
                     'SHOT_DISTANCE':'distance'}

# %%
df_almostthere = df_almostthere.rename(columns = columns_to_rename)

# %%
#df_game_player_target = df_almostthere[df_almostthere['2pt_or_3pt'] == '3PT Field Goal']

# %%
df_almostthere.head()
# Out:
#    win_probability                                   play_description  \
# 0          0.44613                MISS Curry 28' 3PT Pullup Jump Shot
# 1          0.44769       MISS Curry 26' 3PT Running Pull-Up Jump Shot
# 2          0.44020      Curry 25' 3PT Jump Shot (3 PTS) (Green 1 AST)
# 3          0.38091  MISS Curry 2' Driving Finger Roll Layup#@#Davi...
# 4          0.27725                                MISS Curry 3' Layup
#
#    abs_time   game_id  player_id         player     team_id  \
# 0     111.0  22100002     201939  Stephen Curry  1610612744
# 1     139.0  22100002     201939  Stephen Curry  1610612744
# 2     170.0  22100002     201939  Stephen Curry  1610612744
# 3     343.0  22100002     201939  Stephen Curry  1610612744
# 4     529.0  22100002     201939  Stephen Curry  1610612744
#
#                     team  period  shot_result                       shot_type  \
# 0  Golden State Warriors       1  Missed Shot                Pullup Jump shot
# 1  Golden State Warriors       1  Missed Shot       Running Pull-Up Jump Shot
# 2  Golden State Warriors       1    Made Shot                       Jump Shot
# 3  Golden State Warriors       1  Missed Shot  Driving Finger Roll Layup Shot
# 4  Golden State Warriors       1  Missed Shot                      Layup Shot
#
#        field_goal  distance  LOC_X  LOC_Y       location player_h_v  \
# 0  3PT Field Goal        28   -109    260       L Center    Visitor
# 1  3PT Field Goal        26     48    257       R Center    Visitor
# 2  3PT Field Goal        25   -165    189  L Above Break    Visitor
# 3  2PT Field Goal         1    -13     12            NaN    Visitor
# 4  2PT Field Goal         2    -15     22            NaN    Visitor
#
#    score_margin  play_points  points  shots_taken  shots_hit  game_pct
# 0             2            0       0            1          0      0.00
# 1             2            0       0            2          0      0.00
# 2             3            3       3            3          1      0.33
# 3            -2            0       3            4          1      0.25
# 4            -7            0       3            5          1      0.20

# %% [markdown]
# ### Add on's for clean up:

# %%
#let's reset the index to game_id:
#first, setting index:
df_almostthere.set_index('game_id', inplace=True)

# %%
#replacing shot_result string to only say 'missed' and 'made'
df_almostthere.shot_result = df_almostthere.shot_result.replace({'Missed Shot':'Missed', 'Made Shot':'Made'})

# %%
df_almostthere.head()
# Out:
#           win_probability                                   play_description  \
# game_id
# 22100002          0.44613                MISS Curry 28' 3PT Pullup Jump Shot
# 22100002          0.44769       MISS Curry 26' 3PT Running Pull-Up Jump Shot
# 22100002          0.44020      Curry 25' 3PT Jump Shot (3 PTS) (Green 1 AST)
# 22100002          0.38091  MISS Curry 2' Driving Finger Roll Layup#@#Davi...
# 22100002          0.27725                                MISS Curry 3' Layup
#
#           abs_time  player_id         player     team_id  \
# game_id
# 22100002     111.0     201939  Stephen Curry  1610612744
# 22100002     139.0     201939  Stephen Curry  1610612744
# 22100002     170.0     201939  Stephen Curry  1610612744
# 22100002     343.0     201939  Stephen Curry  1610612744
# 22100002     529.0     201939  Stephen Curry  1610612744
#
#                            team  period shot_result  \
# game_id
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1        Made
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1      Missed
#
#                                shot_type      field_goal  distance  LOC_X  \
# game_id
# 22100002                Pullup Jump shot  3PT Field Goal        28   -109
# 22100002       Running Pull-Up Jump Shot  3PT Field Goal        26     48
# 22100002                       Jump Shot  3PT Field Goal        25   -165
# 22100002  Driving Finger Roll Layup Shot  2PT Field Goal         1    -13
# 22100002                      Layup Shot  2PT Field Goal         2    -15
#
#           LOC_Y       location player_h_v  score_margin  play_points  points  \
# game_id
# 22100002    260       L Center    Visitor             2            0       0
# 22100002    257       R Center    Visitor             2            0       0
# 22100002    189  L Above Break    Visitor             3            3       3
# 22100002     12            NaN    Visitor            -2            0       3
# 22100002     22            NaN    Visitor            -7            0       3
#
#           shots_taken  shots_hit  game_pct
# game_id
# 22100002            1          0      0.00
# 22100002            2          0      0.00
# 22100002            3          1      0.33
# 22100002            4          1      0.25
# 22100002            5          1      0.20

# %% [markdown]
# ________________________________________________

# %%
#plotting data for shots in game:
shotsGame = df_almostthere[['abs_time','play_points','points','shots_taken','shots_hit','location','field_goal']].drop_duplicates()

# %%
#just looking at what it holds:
shotsGame.head()
# Out:
#           abs_time  play_points  points  shots_taken  shots_hit  \
# game_id
# 22100002     111.0            0       0            1          0
# 22100002     139.0            0       0            2          0
# 22100002     170.0            3       3            3          1
# 22100002     343.0            0       3            4          1
# 22100002     529.0            0       3            5          1
#
#                location      field_goal
# game_id
# 22100002       L Center  3PT Field Goal
# 22100002       R Center  3PT Field Goal
# 22100002  L Above Break  3PT Field Goal
# 22100002            NaN  2PT Field Goal
# 22100002            NaN  2PT Field Goal

# %% [markdown]
# #### Looking at where Malik is taking the most 3pt shots this game:

# %%
sns.catplot(data=shotsGame, kind='box', x='field_goal', y='abs_time', aspect=1.8, palette ='deep')

# %%
sns.catplot(data=shotsGame, kind='box', x='play_points', y='abs_time', aspect=1.8, palette ='deep')

# %% [markdown]
# ___________________________

# %% [markdown]
# ### Some simple EDA on TimberWolves vs Thunder game- player Malik Beasley:

# %%
df_almostthere
# Out:
#           win_probability                                   play_description  \
# game_id
# 22100002          0.44613                MISS Curry 28' 3PT Pullup Jump Shot
# 22100002          0.44769       MISS Curry 26' 3PT Running Pull-Up Jump Shot
# 22100002          0.44020      Curry 25' 3PT Jump Shot (3 PTS) (Green 1 AST)
# 22100002          0.38091  MISS Curry 2' Driving Finger Roll Layup#@#Davi...
# 22100002          0.27725                                MISS Curry 3' Layup
# 22100002          0.27376                        MISS Curry 2' Driving Layup
# 22100002          0.35274         Curry 3' Driving Finger Roll Layup (8 PTS)
# 22100002          0.37707       MISS Curry 26' 3PT Running Pull-Up Jump Shot
#
# 22100002       9           26          4      0.15
# 22100002      12           27          5      0.19
# 22100002      12           28          5      0.18
# 22100002      12           29          5      0.17

# %%
df_almostthere.describe()
# Out:
#        win_probability     abs_time  player_id       team_id     period  \
# count        27.000000    29.000000       29.0  2.900000e+01  29.000000
# mean          0.313072  1364.275862   201939.0  1.610613e+09   2.206897
# std           0.122786   767.533661        0.0  0.000000e+00   1.013456
# min           0.139290   111.000000   201939.0  1.610613e+09   1.000000
# 25%           0.240095   719.000000   201939.0  1.610613e+09   1.000000
# 50%           0.338740  1273.000000   201939.0  1.610613e+09   2.000000
# 75%           0.364905  1998.000000   201939.0  1.610613e+09   3.000000
# max           0.713090  2815.000000   201939.0  1.610613e+09   4.000000
#
#         distance       LOC_X       LOC_Y  score_margin  play_points  \
# count  29.000000   29.000000   29.000000     29.000000    29.000000
# mean   10.551724  -21.896552   82.275862     -2.620690     0.413793
# std    10.917176   86.305249   96.147170      5.024325     0.945563
# min     1.000000 -238.000000    6.000000     -8.000000     0.000000
# 25%     2.000000  -15.000000   18.000000     -6.000000     0.000000
# 50%     2.000000   -9.000000   21.000000     -3.000000     0.000000
# 75%    23.000000    7.000000  131.000000     -2.000000     0.000000
# max    28.000000  135.000000  260.000000     12.000000     3.000000
#
#           points  shots_taken  shots_hit   game_pct
# count  29.000000    29.000000  29.000000  29.000000
# mean    6.137931    15.000000   2.551724   0.172414
# std     3.090586     8.514693   1.378047   0.065882
# min     0.000000     1.000000   0.000000   0.000000
# 25%     5.000000     8.000000   2.000000   0.150000
# 50%     5.000000    15.000000   2.000000   0.170000
# 75%     7.000000    22.000000   3.000000   0.190000
# max    12.000000    29.000000   5.000000   0.330000

# %%
df_almostthere.isnull().sum()
# Out:
# win_probability      2
# play_description     0
# abs_time             0
# player_id            0
# player               0
# team_id              0
# team                 0
# period               0
# shot_result          0
# shot_type            0
# field_goal           0
# distance             0
# LOC_X                0
# LOC_Y                0
# location            20
# player_h_v           0
# score_margin         0
# play_points          0
# points               0
# shots_taken          0
# shots_hit            0
# game_pct             0
# dtype: int64

# %%
df_almostthere.loc[~df_almostthere.index.duplicated(), :]
# Out:
#           win_probability                     play_description  abs_time  \
# game_id
# 22100002          0.44613  MISS Curry 28' 3PT Pullup Jump Shot     111.0
#
#           player_id         player     team_id                   team  period  \
# game_id
# 22100002     201939  Stephen Curry  1610612744  Golden State Warriors       1
#
#          shot_result         shot_type      field_goal  distance  LOC_X  \
# game_id
# 22100002      Missed  Pullup Jump shot  3PT Field Goal        28   -109
#
#           LOC_Y  location player_h_v  score_margin  play_points  points  \
# game_id
# 22100002    260  L Center    Visitor             2            0       0
#
#           shots_taken  shots_hit  game_pct
# game_id
# 22100002            1          0       0.0

# %%
df_almostthere.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 22100002 to 22100002
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   win_probability   27 non-null     float64
#  1   play_description  29 non-null     object
#  2   abs_time          29 non-null     float64
#  3   player_id         29 non-null     int64
#  4   player            29 non-null     object
#  5   team_id           29 non-null     int64
#  6   team              29 non-null     object
#  7   period            29 non-null     int64
#  8   shot_result       29 non-null     object
#  9   shot_type         29 non-null     object
#  10  field_goal        29 non-null     object
#  11  distance          29 non-null     int64
#  12  LOC_X             29 non-null     int64
#  13  LOC_Y             29 non-null     int64
#  14  location          9 non-null      object
#  15  player_h_v        29 non-null     object
#  16  score_margin      29 non-null     int64
#  17  play_points       29 non-null     int64
#  18  points            29 non-null     int64
#  19  shots_taken       29 non-null     int64
#  20  shots_hit         29 non-null     int64
#  21  game_pct          29 non-null     float64
# dtypes: float64(3), int64(11), object(8)
# memory usage: 6.3+ KB

# %%
#creating a column of shot_result to made = 1, missed = 0 for charts-sake:
df_almostthere['bool_shot_result'] = df_almostthere.shot_result.astype(bool)
#then making this column into integer for the 1 and o
df_almostthere.bool_shot_result=df_almostthere.bool_shot_result.astype(int)

df_almostthere.head()
# Out:
#           win_probability                                   play_description  \
# game_id
# 22100002          0.44613                MISS Curry 28' 3PT Pullup Jump Shot
# 22100002          0.44769       MISS Curry 26' 3PT Running Pull-Up Jump Shot
# 22100002          0.44020      Curry 25' 3PT Jump Shot (3 PTS) (Green 1 AST)
# 22100002          0.38091  MISS Curry 2' Driving Finger Roll Layup#@#Davi...
# 22100002          0.27725                                MISS Curry 3' Layup
#
#           abs_time  player_id         player     team_id  \
# game_id
# 22100002     111.0     201939  Stephen Curry  1610612744
# 22100002     139.0     201939  Stephen Curry  1610612744
# 22100002     170.0     201939  Stephen Curry  1610612744
# 22100002     343.0     201939  Stephen Curry  1610612744
# 22100002     529.0     201939  Stephen Curry  1610612744
#
#                            team  period shot_result  \
# game_id
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1        Made
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1      Missed
#
#                                shot_type      field_goal  distance  LOC_X  \
# game_id
# 22100002                Pullup Jump shot  3PT Field Goal        28   -109
# 22100002       Running Pull-Up Jump Shot  3PT Field Goal        26     48
# 22100002                       Jump Shot  3PT Field Goal        25   -165
# 22100002  Driving Finger Roll Layup Shot  2PT Field Goal         1    -13
# 22100002                      Layup Shot  2PT Field Goal         2    -15
#
#           LOC_Y       location player_h_v  score_margin  play_points  points  \
# game_id
# 22100002    260       L Center    Visitor             2            0       0
# 22100002    257       R Center    Visitor             2            0       0
# 22100002    189  L Above Break    Visitor             3            3       3
# 22100002     12            NaN    Visitor            -2            0       3
# 22100002     22            NaN    Visitor            -7            0       3
#
#           shots_taken  shots_hit  game_pct  bool_shot_result
# game_id
# 22100002            1          0      0.00                 1
# 22100002            2          0      0.00                 1
# 22100002            3          1      0.33                 1
# 22100002            4          1      0.25                 1
# 22100002            5          1      0.20                 1

# %% [markdown]
# ### Univariate Exploration:

# %%
def univariate():
    df_almostthere.hist(bins = 30, figsize = (20, 20), color= 'blue')

# %%
univariate()

# %%
#create variables that split data by made or missed shots: 
#create variables that split train by attrition value 
left_train = df_almostthere[df_almostthere['bool_shot_result'] == 1]
stayed_train = df_almostthere[df_almostthere['bool_shot_result'] == 0]

# %%
#looking at 
df_almostthere.shot_result.value_counts()
# Out:
# Missed    24
# Made       5
# Name: shot_result, dtype: int64

# %%
def made_3ptshot_rate():
    labels = 'Missed', 'Made'
    data = [6, 11]
    plt.pie(data, labels=labels, colors = ['#17408B', '#C9082A'])
    plt.show()

# %%
#simple pie chart to show Malik's 3pt shots made/missed rate:
made_3ptshot_rate()

# %% [markdown]
# #### If I drop nulls I drop the whole df for this game, as there are only 17 rows here.

# %%
plt.title("Win Probability relating to 2pt and 3pt shots")
sns.barplot(x="win_probability", y="shot_result", data=df_almostthere)

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
sns.set(rc={'figure.figsize':(17.7,8.27)})
plt.title("Win Probability relating to type of shot made")
sns.barplot(x="win_probability", y="shot_type", data=df_almostthere)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#function from  Savvas Tjortjoglou of how to create an NBA sized court:
from matplotlib.patches import Circle, Rectangle, Arc

def draw_court(ax=None, color='black', lw=2, outer_lines=False):
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 18" so it has a radius of 9", which is a value
    # 7.5 in our coordinate system
    hoop = Circle((0, 0), radius=7.5, linewidth=lw, color=color, fill=False)

    # Create backboard
    backboard = Rectangle((-30, -7.5), 60, -1, linewidth=lw, color=color)

    # The paint
    # Create the outer box 0f the paint, width=16ft, height=19ft
    outer_box = Rectangle((-80, -47.5), 160, 190, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-60, -47.5), 120, 190, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 142.5), 120, 120, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 142.5), 120, 120, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 80, 80, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    # Create the side 3pt lines, they are 14ft long before they begin to arc
    corner_three_a = Rectangle((-220, -47.5), 0, 140, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((220, -47.5), 0, 140, linewidth=lw, color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the 
    # threes
    three_arc = Arc((0, 0), 475, 475, theta1=22, theta2=158, linewidth=lw,
                    color=color)

    # Center Court
    center_outer_arc = Arc((0, 422.5), 120, 120, theta1=180, theta2=0,
                           linewidth=lw, color=color)
    center_inner_arc = Arc((0, 422.5), 40, 40, theta1=180, theta2=0,
                           linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc, center_outer_arc,
                      center_inner_arc]

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-250, -47.5), 500, 470, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

# %%
g=sns.relplot(data=df_almostthere.field_goal, kind = 'scatter',
               x = df_almostthere.LOC_X, y= df_almostthere.LOC_Y, hue= df_almostthere.shot_result)

for i, ax in enumerate(g.axes.flat):
    ax = draw_court(ax, outer_lines=True)
    ax.set_xlim(-300, 300)
    ax.set_ylim(-100, 500)

# %% [markdown]
# ______________________

# %% [markdown]
# ### Hypothesis testing categorical features:

# %%
# Let's run a chi squared to compare proportions, to have more confidence
alpha = 0.05
null_hypothesis = "shot results and shot type are independent"
alternative_hypothesis = "there is a relationship between show results and shot type"

# Setup a crosstab of observed survival to pclass
observed = pd.crosstab(df_almostthere.shot_result, df_almostthere.shot_type)

chi2, p, degf, expected = stats.chi2_contingency(observed)

if p < alpha:
    print("Reject the null hypothesis that", null_hypothesis)
    print("Sufficient evidence to move forward understanding that", alternative_hypothesis)
else:
    print("Fail to reject the null")
    print("Insufficient evidence to reject the null")
p
# Out:
# Fail to reject the null
# Insufficient evidence to reject the null
# 0.16807298256716155

# %%
# Let's run a chi squared to compare proportions, to have more confidence
alpha = 0.05
null_hypothesis = "shot results and period of game are independent"
alternative_hypothesis = "there is a relationship between shot results and period of game"

# Setup a crosstab of observed survival to pclass
observed = pd.crosstab(df_almostthere.shot_result, df_almostthere.period)

chi2, p, degf, expected = stats.chi2_contingency(observed)

if p < alpha:
    print("Reject the null hypothesis that", null_hypothesis)
    print("Sufficient evidence to move forward understanding that", alternative_hypothesis)
else:
    print("Fail to reject the null")
    print("Insufficient evidence to reject the null")
p
# Out:
# Fail to reject the null
# Insufficient evidence to reject the null
# 0.7857698328942306

# %%
# Let's run a chi squared to compare proportions, to have more confidence
alpha = 0.05
null_hypothesis = "shot results and location of shot are independent"
alternative_hypothesis = "there is a relationship between shot results and location of shot"

# Setup a crosstab of observed survival to pclass
observed = pd.crosstab(df_almostthere.shot_result, df_almostthere.location)

chi2, p, degf, expected = stats.chi2_contingency(observed)

if p < alpha:
    print("Reject the null hypothesis that", null_hypothesis)
    print("Sufficient evidence to move forward understanding that", alternative_hypothesis)
else:
    print("Fail to reject the null")
    print("Insufficient evidence to reject the null")
p
# Out:
# Fail to reject the null
# Insufficient evidence to reject the null
# 0.19128838857837355

# %% [markdown]
# ### Takeaways:
# Because this is only one game and it shows that any sort of results/data to be understood--we need more data.

# %%
df_almostthere.head()
# Out:
#           win_probability                                   play_description  \
# game_id
# 22100002          0.44613                MISS Curry 28' 3PT Pullup Jump Shot
# 22100002          0.44769       MISS Curry 26' 3PT Running Pull-Up Jump Shot
# 22100002          0.44020      Curry 25' 3PT Jump Shot (3 PTS) (Green 1 AST)
# 22100002          0.38091  MISS Curry 2' Driving Finger Roll Layup#@#Davi...
# 22100002          0.27725                                MISS Curry 3' Layup
#
#           abs_time  player_id         player     team_id  \
# game_id
# 22100002     111.0     201939  Stephen Curry  1610612744
# 22100002     139.0     201939  Stephen Curry  1610612744
# 22100002     170.0     201939  Stephen Curry  1610612744
# 22100002     343.0     201939  Stephen Curry  1610612744
# 22100002     529.0     201939  Stephen Curry  1610612744
#
#                            team  period shot_result  \
# game_id
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1        Made
# 22100002  Golden State Warriors       1      Missed
# 22100002  Golden State Warriors       1      Missed
#
#                                shot_type      field_goal  distance  LOC_X  \
# game_id
# 22100002                Pullup Jump shot  3PT Field Goal        28   -109
# 22100002       Running Pull-Up Jump Shot  3PT Field Goal        26     48
# 22100002                       Jump Shot  3PT Field Goal        25   -165
# 22100002  Driving Finger Roll Layup Shot  2PT Field Goal         1    -13
# 22100002                      Layup Shot  2PT Field Goal         2    -15
#
#           LOC_Y       location player_h_v  score_margin  play_points  points  \
# game_id
# 22100002    260       L Center    Visitor             2            0       0
# 22100002    257       R Center    Visitor             2            0       0
# 22100002    189  L Above Break    Visitor             3            3       3
# 22100002     12            NaN    Visitor            -2            0       3
# 22100002     22            NaN    Visitor            -7            0       3
#
#           shots_taken  shots_hit  game_pct  bool_shot_result
# game_id
# 22100002            1          0      0.00                 1
# 22100002            2          0      0.00                 1
# 22100002            3          1      0.33                 1
# 22100002            4          1      0.25                 1
# 22100002            5          1      0.20                 1

# %%
for i, predictor in enumerate(df_almostthere.drop(columns=["win_probability","abs_time","player_id","player","team_id","distance","LOC_X","LOC_Y","score_margin","play_points","points","shots_taken","shots_hit","game_pct","bool_shot_result"])):
    plt.figure(i)
    plot= sns.countplot(data=df_almostthere, x=predictor, hue='shot_result')
    plt.setp(plot.get_xticklabels(), rotation=45)

# %%
df_almostthere.columns
# Out:
# Index(['win_probability', 'play_description', 'abs_time', 'player_id',
#        'player', 'team_id', 'team', 'period', 'shot_result', 'shot_type',
#        'field_goal', 'distance', 'LOC_X', 'LOC_Y', 'location', 'player_h_v',
#        'score_margin', 'play_points', 'points', 'shots_taken', 'shots_hit',
#        'game_pct', 'bool_shot_result'],
#       dtype='object')

# %%
df_almostthere.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 22100002 to 22100002
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   win_probability   27 non-null     float64
#  1   play_description  29 non-null     object
#  2   abs_time          29 non-null     float64
#  3   player_id         29 non-null     int64
#  4   player            29 non-null     object
#  5   team_id           29 non-null     int64
#  6   team              29 non-null     object
#  7   period            29 non-null     int64
#  8   shot_result       29 non-null     object
#  9   shot_type         29 non-null     object
#  10  field_goal        29 non-null     object
#  11  distance          29 non-null     int64
#  12  LOC_X             29 non-null     int64
#  13  LOC_Y             29 non-null     int64
#  14  location          9 non-null      object
#  15  player_h_v        29 non-null     object
#  16  score_margin      29 non-null     int64
#  17  play_points       29 non-null     int64
#  18  points            29 non-null     int64
#  19  shots_taken       29 non-null     int64
#  20  shots_hit         29 non-null     int64
#  21  game_pct          29 non-null     float64
#  22  bool_shot_result  29 non-null     int64
# dtypes: float64(3), int64(12), object(8)
# memory usage: 6.5+ KB

# %%
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

newdf = df_almostthere.select_dtypes(include=numerics)
newdf.head()
# Out:
#           win_probability  abs_time  player_id     team_id  period  distance  \
# game_id
# 22100002          0.44613     111.0     201939  1610612744       1        28
# 22100002          0.44769     139.0     201939  1610612744       1        26
# 22100002          0.44020     170.0     201939  1610612744       1        25
# 22100002          0.38091     343.0     201939  1610612744       1         1
# 22100002          0.27725     529.0     201939  1610612744       1         2
#
#           LOC_X  LOC_Y  score_margin  play_points  points  shots_taken  \
# game_id
# 22100002   -109    260             2            0       0            1
# 22100002     48    257             2            0       0            2
# 22100002   -165    189             3            3       3            3
# 22100002    -13     12            -2            0       3            4
# 22100002    -15     22            -7            0       3            5
#
#           shots_hit  game_pct  bool_shot_result
# game_id
# 22100002          0      0.00                 1
# 22100002          0      0.00                 1
# 22100002          1      0.33                 1
# 22100002          1      0.25                 1
# 22100002          1      0.20                 1

# %%
for i, predictor in enumerate(newdf.select_dtypes(include= numerics)):
    plt.figure(i)
    plot= sns.relplot(data=newdf, y=predictor, x='abs_time')
#     plt.setp(plot.get_xticklabels(), rotation=45)

# %% [markdown]
# __________________________
